# %%
import cantera as ct
import yaml

# %%
uncertainty_file = '/home/moon/autoscience/uncertainty/partial_nheptane/nheptane_uncertainty2.yaml'
mechanism_file = '/home/moon/autoscience/uncertainty/partial_nheptane/nheptane_mech_main/nheptane.yaml'

# %%
# Read in the mechanism and the uncertainty files
# Order of reactions is preserved between the two files
with open(uncertainty_file, 'r') as file:
    mech_uncertainty = yaml.load(file, Loader=yaml.FullLoader)

gas1 = ct.Solution(mechanism_file)

# %% [markdown]
# # Print a table of reaction uncertainty sources

# %%
print('#\tReaction\t\t\t\t\t\t\tSource')
print('-------------------------------------------------------------------------------')
N = 60
for i, rxn in enumerate(gas1.reactions()):
    pad_length = N - len(rxn.equation)
    rxn_str = str(rxn) + " " * pad_length

    source = mech_uncertainty['reactions'][i]['uncertainty']['source']
    print(i, f'\t{rxn_str}\t{source}')
# Out:
# #	Reaction							Source
# -------------------------------------------------------------------------------
# 0 	H(14) + O2(2) <=> O(5) + OH(15)                             	Library
# 1 	H2(13) + O(5) <=> H(14) + OH(15)                            	Library
# 2 	H2(13) + O(5) <=> H(14) + OH(15)                            	Library
# 3 	H2(13) + OH(15) <=> H(14) + H2O(8)                          	Library
# 4 	2 OH(15) <=> H2O(8) + O(5)                                  	Library
# 5 	H2(13) + M <=> 2 H(14) + M                                  	Library
# 6 	Ar + H2(13) <=> Ar + 2 H(14)                                	Library
# 7 	H2(13) + He(16) <=> 2 H(14) + He(16)                        	Library
# 8 	2 O(5) + M <=> O2(2) + M                                    	Library
# 9 	Ar + 2 O(5) <=> Ar + O2(2)                                  	Library
# 10 	He(16) + 2 O(5) <=> He(16) + O2(2)                          	Library
# 11 	H(14) + O(5) + M <=> OH(15) + M                             	Library
# 12 	H2O(8) + M <=> H(14) + OH(15) + M                           	Library
# 13 	2 H2O(8) <=> H(14) + H2O(8) + OH(15)                        	Library
# 14 	H(14) + O2(2) (+M) <=> HO2(17) (+M)                         	Library
# 15 	H(14) + HO2(17) <=> H2(13) + O2(2)                          	Library
# 16 	H(14) + HO2(17) <=> 2 OH(15)                                	Library
# 17 	HO2(17) + O(5) <=> O2(2) + OH(15)                           	Library
# 18 	HO2(17) + OH(15) <=> H2O(8) + O2(2)                         	Library
# 19 	2 HO2(17) <=> H2O2(18) + O2(2)                              	Library
# 20 	2 HO2(17) <=> H2O2(18) + O2(2)                              	Library
# 21 	H2O2(18) (+M) <=> 2 OH(15) (+M)                             	Library
# 22 	H(14) + H2O2(18) <=> H2O(8) + OH(15)                        	Library
# 23 	H(14) + H2O2(18) <=> H2(13) + HO2(17)                       	Library
# 24 	H2O2(18) + O(5) <=> HO2(17) + OH(15)                        	Library
# 25 	H2O2(18) + OH(15) <=> H2O(8) + HO2(17)                      	Library
# 26 	H2O2(18) + OH(15) <=> H2O(8) + HO2(17)                      	Library
# 27 	H(14) + HO2(17) <=> H2O(8) + O(5)                           	Library
# 28 	H(14) + HO2(17) + M <=> H2O2(18) + M                        	Library
# 29 	2 OH(15) <=> H2(13) + O2(2)                                 	Library
# 30 	H2O(8) + O(5) <=> H2(13) + O2(2)                            	Library
# 31 	H2O2(18) + O(5) <=> H2O(8) + O2(2)                          	Library
# 32 	O(5) + OH(15) + M <=> HO2(17) + M                           	Library
# 33 	C2H4(11) + O(5) <=> CH3(19) + HCO(20)                       	Library
# 34 	C2H4(11) + O(5) <=> CH3CO(21) + H(14)                       	Library
# 35 	C2H4(11) + O(5) <=> CH2CHO(22) + H(14)                      	Library
# 36 	C2H4(11) + O(5) <=> C2H3(23) + OH(15)                       	Library
# 37 	C2H4(11) + O(5) <=> CH2(24) + CH2O(9)                       	Library
# 38 	C2H4(11) + O(5) <=> CH2CO(25) + H2(13)                      	Library
# 39 	C2H4(11) + O(5) <=> CH4(10) + CO(6)                         	Library
# 40 	C2H4(11) + O(5) <=> C2H2(26) + H2O(8)                       	Library
# 41 	CH2(24) + H(14) (+M) <=> CH3(19) (+M)                       	Library
# 42 	CH2CHO(22) (+M) <=> CH2CO(25) + H(14) (+M)                  	Library
# 43 	CH3CO(21) (+M) <=> CH2CO(25) + H(14) (+M)                   	Library
# 44 	C2H2(26) + H(14) (+M) <=> C2H3(23) (+M)                     	Library
# 45 	C2H2(26) + HO2(17) <=> CH2CO(25) + OH(15)                   	Library
# 46 	C2H2(26) + OH(15) <=> CH2CO(25) + H(14)                     	Library
# 47 	2 CH2(24) <=> C2H2(26) + 2 H(14)                            	Library
# 48 	C2H3(23) + OH(15) <=> CH3(19) + HCO(20)                     	Library
# 49 	C2H3(23) + OH(15) <=> CH3CO(21) + H(14)                     	Library
# 50 	CH2CHO(22) + H(14) <=> CH3(19) + HCO(20)                    	Library
# 51 	CH2CHO(22) + H(14) <=> CH3CO(21) + H(14)                    	Library
# 52 	CH3CO(21) + H(14) <=> CH3(19) + HCO(20)                     	Library
# 53 	C2H3(23) + CH2(24) <=> C2H2(26) + CH3(19)                   	Library
# 54 	CH2(24) + O2(2) <=> HCO(20) + OH(15)                        	Library
# 55 	CH2CHO(22) + O2(2) <=> CH2CO(25) + HO2(17)                  	Library
# 56 	C2H3(23) + O2(2) <=> C2H2(26) + HO2(17)                     	Library
# 57 	C2H3(23) + O2(2) <=> C2H2(26) + HO2(17)                     	Library
# 58 	C2H3(23) + O2(2) <=> CH2CO(25) + OH(15)                     	Library
# 59 	C2H3(23) + O2(2) <=> CH2CO(25) + OH(15)                     	Library
# 60 	CH3CO(21) + O2(2) <=> CH2CO(25) + HO2(17)                   	Library
# 61 	CH(3) + OH(15) <=> H(14) + HCO(20)                          	Library
# 62 	CH(3) + CH2(24) <=> C2H2(26) + H(14)                        	Library
# 63 	CH(3) + CH3(19) <=> C2H3(23) + H(14)                        	Library
# 64 	C2H(4) + H(14) (+M) <=> C2H2(26) (+M)                       	Library
# 65 	CH(3) + O2(2) <=> HCO(20) + O(5)                            	Library
# 66 	CH3CO(21) + O(5) <=> CH2CO(25) + OH(15)                     	Library
# 67 	C2H3(23) + O2(2) <=> CH2CHO(22) + O(5)                      	Library
# 68 	C2H3(23) + O2(2) <=> CH2CHO(22) + O(5)                      	Library
# 69 	CH2CO(25) + O(5) <=> 2 HCO(20)                              	Library
# 70 	C2H3(23) + O(5) <=> CH2CO(25) + H(14)                       	Library
# 71 	HCO(20) + M <=> CO(6) + H(14) + M                           	Library
# 72 	HCO(20) + O2(2) <=> CO(6) + HO2(17)                         	Library
# 73 	HCO(20) + O(5) <=> CO(6) + OH(15)                           	Library
# 74 	CH2(24) + O(5) => CO(6) + 2 H(14)                           	Library
# 75 	CH(3) + O(5) <=> CO(6) + H(14)                              	Library
# 76 	CH3CO(21) (+M) <=> CH3(19) + CO(6) (+M)                     	Library
# 77 	CH2CHO(22) (+M) <=> CH3(19) + CO(6) (+M)                    	Library
# 78 	CH2(24) + CO(6) (+M) <=> CH2CO(25) (+M)                     	Library
# 79 	CH2CO(25) + H(14) <=> CH3(19) + CO(6)                       	Library
# 80 	C2H(4) + O(5) <=> CH(3) + CO(6)                             	Library
# 81 	C2H(4) + O2(2) <=> CO(6) + HCO(20)                          	Library
# 82 	C2H2(26) + O(5) <=> CH2(24) + CO(6)                         	Library
# 83 	C2H2(26) + OH(15) <=> CH3(19) + CO(6)                       	Library
# 84 	C2H2(26) + HCO(20) <=> C2H3(23) + CO(6)                     	Library
# 85 	CH(3) + O2(2) <=> CO(6) + OH(15)                            	Library
# 86 	CH(3) + O2(2) <=> CO(6) + H(14) + O(5)                      	Library
# 87 	CH2(24) + O2(2) <=> CO(6) + H(14) + OH(15)                  	Library
# 88 	CH(3) + CH2CO(25) <=> C2H3(23) + CO(6)                      	Library
# 89 	CH3CO(21) + OH(15) <=> CH3(19) + CO(6) + OH(15)             	Library
# 90 	CH2CO(25) + O(5) <=> CO(6) + H(14) + HCO(20)                	Library
# 91 	C2H(4) + OH(15) <=> CH2(24) + CO(6)                         	Library
# 92 	C2H3(23) + O(5) <=> CH3(19) + CO(6)                         	Library
# 93 	CH2(24) + HCO(20) <=> CH3(19) + CO(6)                       	Library
# 94 	CO(6) + O(5) (+M) <=> CO2(7) (+M)                           	Library
# 95 	CO(6) + O2(2) <=> CO2(7) + O(5)                             	Library
# 96 	CO(6) + OH(15) <=> CO2(7) + H(14)                           	Library
# 97 	CO(6) + OH(15) <=> CO2(7) + H(14)                           	Library
# 98 	CO(6) + HO2(17) <=> CO2(7) + OH(15)                         	Library
# 99 	HCO(20) + O(5) <=> CO2(7) + H(14)                           	Library
# 100 	HCO(20) + HO2(17) => CO2(7) + H(14) + OH(15)                	Library
# 101 	CH2(24) + O2(2) => CO2(7) + 2 H(14)                         	Library
# 102 	CH(3) + CO2(7) <=> CO(6) + HCO(20)                          	Library
# 103 	CH2CO(25) + O(5) <=> CH2(24) + CO2(7)                       	Library
# 104 	C2H3(23) + O2(2) <=> CH3(19) + CO2(7)                       	Library
# 105 	C2H3(23) + O2(2) <=> CH3(19) + CO2(7)                       	Library
# 106 	CH(3) + O2(2) <=> CO2(7) + H(14)                            	Library
# 107 	CH2CO(25) + OH(15) <=> CH3(19) + CO2(7)                     	Library
# 108 	CH2CHO(22) + O(5) <=> CH2(24) + CO2(7) + H(14)              	Library
# 109 	CH3CO(21) + O(5) <=> CH3(19) + CO2(7)                       	Library
# 110 	CH3CO(21) + HO2(17) <=> CH3(19) + CO2(7) + OH(15)           	Library
# 111 	HCO(20) + OH(15) <=> CO(6) + H2O(8)                         	Library
# 112 	CH3(19) + OH(15) <=> CH2(24) + H2O(8)                       	Library
# 113 	CH2(24) + OH(15) <=> CH(3) + H2O(8)                         	Library
# 114 	C2H3(23) + OH(15) <=> C2H2(26) + H2O(8)                     	Library
# 115 	C2H2(26) + OH(15) <=> C2H(4) + H2O(8)                       	Library
# 116 	CH2(24) + O2(2) <=> CO(6) + H2O(8)                          	Library
# 117 	CH2CHO(22) + OH(15) <=> CH2CO(25) + H2O(8)                  	Library
# 118 	CH3CO(21) + OH(15) <=> CH2CO(25) + H2O(8)                   	Library
# 119 	H(14) + H2O(8) + O2(2) <=> H2O(8) + HO2(17)                 	Library
# 120 	CH2O(9) + O2(2) <=> HCO(20) + HO2(17)                       	Library
# 121 	2 HCO(20) <=> CH2O(9) + CO(6)                               	Library
# 122 	H(14) + HCO(20) (+M) <=> CH2O(9) (+M)                       	Library
# 123 	CH2O(9) + OH(15) <=> H2O(8) + HCO(20)                       	Library
# 124 	CH2O(9) + O(5) <=> HCO(20) + OH(15)                         	Library
# 125 	CH2O(9) + HO2(17) <=> H2O2(18) + HCO(20)                    	Library
# 126 	CH3(19) + O(5) <=> CH2O(9) + H(14)                          	Library
# 127 	CH3(19) + O2(2) <=> CH2O(9) + OH(15)                        	Library
# 128 	CH(3) + H2O(8) <=> CH2O(9) + H(14)                          	Library
# 129 	CH2CHO(22) + O2(2) => CH2O(9) + CO(6) + OH(15)              	Library
# 130 	CH(3) + CH2O(9) <=> CH2CO(25) + H(14)                       	Library
# 131 	C2H3(23) + O2(2) <=> CH2O(9) + HCO(20)                      	Library
# 132 	C2H3(23) + O2(2) <=> CH2O(9) + HCO(20)                      	Library
# 133 	C2H3(23) + O2(2) <=> CH2O(9) + CO(6) + H(14)                	Library
# 134 	C2H3(23) + O2(2) <=> CH2O(9) + CO(6) + H(14)                	Library
# 135 	CH2(24) + OH(15) <=> CH2O(9) + H(14)                        	Library
# 136 	CH2(24) + HO2(17) <=> CH2O(9) + OH(15)                      	Library
# 137 	CH2(24) + O2(2) <=> CH2O(9) + O(5)                          	Library
# 138 	CH2(24) + CH2O(9) <=> CH3(19) + HCO(20)                     	Library
# 139 	C2H(4) + CH2O(9) <=> C2H2(26) + HCO(20)                     	Library
# 140 	CH2CO(25) + O(5) <=> CH2O(9) + CO(6)                        	Library
# 141 	CH2(24) + CO2(7) <=> CH2O(9) + CO(6)                        	Library
# 142 	CH3(19) + HCO(20) <=> CH4(10) + CO(6)                       	Library
# 143 	CH2O(9) + CH3(19) <=> CH4(10) + HCO(20)                     	Library
# 144 	CH3(19) + H(14) (+M) <=> CH4(10) (+M)                       	Library
# 145 	CH4(10) + OH(15) <=> CH3(19) + H2O(8)                       	Library
# 146 	CH4(10) + O(5) <=> CH3(19) + OH(15)                         	Library
# 147 	CH4(10) + HO2(17) <=> CH3(19) + H2O2(18)                    	Library
# 148 	CH2(24) + CH4(10) <=> 2 CH3(19)                             	Library
# 149 	CH3(19) + HO2(17) <=> CH4(10) + O2(2)                       	Library
# 150 	CH3(19) + CH3CO(21) <=> CH2CO(25) + CH4(10)                 	Library
# 151 	C2H3(23) + CH3(19) <=> C2H2(26) + CH4(10)                   	Library
# 152 	C2H(4) + CH4(10) <=> C2H2(26) + CH3(19)                     	Library
# 153 	C2H3(23) + H(14) (+M) <=> C2H4(11) (+M)                     	Library
# 154 	C2H4(11) + OH(15) <=> C2H3(23) + H2O(8)                     	Library
# 155 	C2H4(11) + OH(15) <=> CH2O(9) + CH3(19)                     	Library
# 156 	C2H4(11) + O2(2) <=> C2H3(23) + HO2(17)                     	Library
# 157 	CH(3) + CH4(10) <=> C2H4(11) + H(14)                        	Library
# 158 	2 C2H3(23) <=> C2H2(26) + C2H4(11)                          	Library
# 159 	C2H4(11) + CH3(19) <=> C2H3(23) + CH4(10)                   	Library
# 160 	C2H4(11) + CH3(19) <=> C2H3(23) + CH4(10)                   	Library
# 161 	C2H3(23) + CH2O(9) <=> C2H4(11) + HCO(20)                   	Library
# 162 	CH2(24) + CH3(19) <=> C2H4(11) + H(14)                      	Library
# 163 	C2H3(23) + CH3(19) (+M) <=> C3H6(12) (+M)                   	Library
# 164 	C3H6(12) <=> C2H3(23) + CH3(19)                             	Library
# 165 	C3H6(12) <=> C2H3(23) + CH3(19)                             	Library
# 166 	C3H6(12) + O(5) => CH2CO(25) + CH3(19) + H(14)              	Library
# 167 	C3H6(12) + H(14) <=> C2H4(11) + CH3(19)                     	Library
# 168 	C3H6(12) + H(14) <=> C2H4(11) + CH3(19)                     	Library
# 169 	H(14) + HCO(20) <=> CO(6) + H2(13)                          	Library
# 170 	2 HCO(20) => 2 CO(6) + H2(13)                               	Library
# 171 	CO(6) + H2(13) (+M) <=> CH2O(9) (+M)                        	Library
# 172 	CH2O(9) + H(14) <=> H2(13) + HCO(20)                        	Library
# 173 	CH4(10) + H(14) <=> CH3(19) + H2(13)                        	Library
# 174 	CH3(19) + OH(15) <=> CH2O(9) + H2(13)                       	Library
# 175 	CH3CO(21) + H(14) <=> CH2CO(25) + H2(13)                    	Library
# 176 	C2H4(11) + H(14) <=> C2H3(23) + H2(13)                      	Library
# 177 	C2H3(23) + H(14) <=> C2H2(26) + H2(13)                      	Library
# 178 	C2H(4) + H2(13) <=> C2H2(26) + H(14)                        	Library
# 179 	CH(3) + H2(13) <=> CH2(24) + H(14)                          	Library
# 180 	CH(3) + H2(13) (+M) <=> CH3(19) (+M)                        	Library
# 181 	CH2(24) + H2(13) <=> CH3(19) + H(14)                        	Library
# 182 	CH2(24) + O2(2) <=> CO2(7) + H2(13)                         	Library
# 183 	CH3(19) + O(5) <=> CO(6) + H(14) + H2(13)                   	Library
# 184 	CH2CHO(22) + H(14) <=> CH2CO(25) + H2(13)                   	Library
# 185 	CH2(24) + O(5) <=> CO(6) + H2(13)                           	Library
# 186 	2 CH2(24) <=> C2H2(26) + H2(13)                             	Library
# 187 	C2H4(11) + M <=> C2H2(26) + H2(13) + M                      	Library
# 188 	C2H4(11) + H(14) (+M) <=> C2H5(44) (+M)                     	Library
# 189 	2 C2H4(11) <=> C2H3(23) + C2H5(44)                          	Library
# 190 	C2H5(44) + CH3(19) <=> C2H4(11) + CH4(10)                   	Library
# 191 	2 CH3(19) <=> C2H5(44) + H(14)                              	Library
# 192 	C2H5(44) + H(14) <=> C2H4(11) + H2(13)                      	Library
# 193 	C2H5(44) + O2(2) <=> C2H4(11) + HO2(17)                     	Library
# 194 	C2H5(44) + O2(2) <=> C2H4(11) + HO2(17)                     	Library
# 195 	CH2CO(25) + CH3(19) <=> C2H5(44) + CO(6)                    	Library
# 196 	C3H6(12) + O(5) <=> C2H5(44) + HCO(20)                      	Library
# 197 	C2H5(44) + O(5) <=> CH2O(9) + CH3(19)                       	Library
# 198 	C2H5(44) + O(5) <=> C2H4(11) + OH(15)                       	Library
# 199 	C2H5(44) + C5H11(421) <=> C7H16(1)                          	Rate Rules
# 200 	C2H5(44) <=> CH2(24) + CH3(19)                              	PDep
# 201 	PC4H9(183) <=> C2H4(11) + C2H5(44)                          	Library
# 202 	C5H11(421) <=> CH2(24) + PC4H9(183)                         	PDep
# 203 	NC3H7(93) + O2(2) <=> C3H6(12) + HO2(17)                    	Library
# 204 	C3H6(12) + H(14) <=> NC3H7(93)                              	Library
# 205 	C3H6(12) + H(14) <=> NC3H7(93)                              	Library
# 206 	C2H4(11) + CH3(19) <=> NC3H7(93)                            	Library
# 207 	C2H4(11) + CH3(19) <=> NC3H7(93)                            	Library
# 208 	C5H11(421) <=> C2H4(11) + NC3H7(93)                         	Library
# 209 	NC3H7(93) + PC4H9(183) <=> C7H16(1)                         	Rate Rules
# 210 	CH2(24) + HO2(17) <=> CH3(19) + O2(2)                       	Rate Rules
# 211 	CH2CHO(22) <=> CH2(24) + HCO(20)                            	PDep
# 212 	CH2CHO(22) <=> C2H3(23) + O(5)                              	PDep
# 213 	CH2CHO(22) <=> CH3CO(21)                                    	PDep
# 214 	PC4H9(183) <=> CH2(24) + NC3H7(93)                          	PDep
# 215 	NC3H7(93) <=> C2H5(44) + CH2(24)                            	PDep
# 216 	C5H11(421) <=> C5H11(422)                                   	Library
# 217 	C5H11(422) <=> C2H5(44) + C3H6(12)                          	Library
# 218 	O2(2) + PC4H9(183) <=> S(185)                               	Library
# 219 	NC3H7(93) + O2(2) <=> C3H7O2(96)                            	Library
# 220 	C3H7O2(96) <=> C3H6(12) + HO2(17)                           	Library
# 221 	C2H5(44) + O2(2) <=> C2H5O2(45)                             	Library
# 222 	C2H5O2(45) <=> C2H4(11) + HO2(17)                           	Library
# 223 	C5H11(421) + O2(2) <=> S(436)                               	Library
# 224 	C2H5(44) + O2(2) <=> C2H4O(50) + OH(15)                     	Library
# 225 	C2H5O2(45) <=> C2H4O(50) + OH(15)                           	Library
# 226 	C2H4O(50) <=> CH3(19) + HCO(20)                             	Library
# 227 	C2H4(11) + HO2(17) <=> C2H4O(50) + OH(15)                   	Library
# 228 	S(436) <=> S(443)                                           	Library
# 229 	C7H15(682) + H(14) <=> C7H16(1)                             	Rate Rules
# 230 	C7H15(682) + HO2(17) <=> C7H16(1) + O2(2)                   	Rate Rules
# 231 	C7H16(1) + O(5) <=> C7H15(682) + OH(15)                     	Rate Rules
# 232 	C7H16(1) + OH(15) <=> C7H15(682) + H2O(8)                   	Rate Rules
# 233 	C7H15(682) + H2O2(18) <=> C7H16(1) + HO2(17)                	Rate Rules
# 234 	C2H5(44) + C7H15(682) <=> C2H4(11) + C7H16(1)               	Rate Rules
# 235 	C7H16(1) + H(14) <=> C7H15(682) + H2(13)                    	Rate Rules
# 236 	C7H16(1) + CH3(19) <=> C7H15(682) + CH4(10)                 	Rate Rules
# 237 	C7H15(682) + NC3H7(93) <=> C3H6(12) + C7H16(1)              	Rate Rules
# 238 	C3H6(12) + PC4H9(183) <=> C7H15(682)                        	Rate Rules
# 239 	C7H15(682) + O2(2) <=> S(763)                               	Rate Rules
# 240 	S(185) <=> S(220)                                           	Library
# 241 	S(220) => C3H6(12) + CH2O(9) + OH(15)                       	Library
# 242 	C5H11(422) + O2(2) <=> S(438)                               	Library
# 243 	S(436) <=> S(444)                                           	Library
# 244 	S(443) <=> S(444)                                           	Rate Rules
# 245 	C7H15(679) + H(14) <=> C7H16(1)                             	Rate Rules
# 246 	C7H15(679) + HO2(17) <=> C7H16(1) + O2(2)                   	Rate Rules
# 247 	C7H16(1) + O(5) <=> C7H15(679) + OH(15)                     	Rate Rules
# 248 	C7H16(1) + OH(15) <=> C7H15(679) + H2O(8)                   	Rate Rules
# 249 	C7H15(679) + H2O2(18) <=> C7H16(1) + HO2(17)                	Rate Rules
# 250 	C2H5(44) + C7H15(679) <=> C2H4(11) + C7H16(1)               	Rate Rules
# 251 	C7H16(1) + H(14) <=> C7H15(679) + H2(13)                    	Rate Rules
# 252 	C7H16(1) + CH3(19) <=> C7H15(679) + CH4(10)                 	Rate Rules
# 253 	C7H15(679) + NC3H7(93) <=> C3H6(12) + C7H16(1)              	Rate Rules
# 254 	C7H15(679) <=> C7H15(682)                                   	Rate Rules
# 255 	C7H15(679) <=> C7H15(682)                                   	Rate Rules
# 256 	C7H15(679) + C7H16(1) <=> C7H15(682) + C7H16(1)             	Rate Rules
# 257 	C7H15(679) <=> C7H15(682)                                   	Rate Rules
# 258 	C7H15(679) <=> C7H15(682)                                   	Rate Rules
# 259 	C7H15(679) + O2(2) <=> S(816)                               	Rate Rules
# 260 	C3H7O2(96) <=> S(115)                                       	Library
# 261 	S(115) => C2H4(11) + CH2O(9) + OH(15)                       	Library
# 262 	S(444) <=> OH(15) + S(454)                                  	Library
# 263 	OH(15) + S(454) => C3H6(12) + CH2CHO(22) + H2O(8)           	Library
# 264 	HO2(17) + S(454) => C3H6(12) + CH2CHO(22) + H2O2(18)        	Library
# 265 	C7H15(680) + H(14) <=> C7H16(1)                             	Rate Rules
# 266 	C7H15(680) + HO2(17) <=> C7H16(1) + O2(2)                   	Rate Rules
# 267 	C7H16(1) + O(5) <=> C7H15(680) + OH(15)                     	Rate Rules
# 268 	C7H16(1) + OH(15) <=> C7H15(680) + H2O(8)                   	Rate Rules
# 269 	C7H15(680) + H2O2(18) <=> C7H16(1) + HO2(17)                	Rate Rules
# 270 	C2H5(44) + C7H15(680) <=> C2H4(11) + C7H16(1)               	Rate Rules
# 271 	C7H16(1) + H(14) <=> C7H15(680) + H2(13)                    	Rate Rules
# 272 	C7H16(1) + CH3(19) <=> C7H15(680) + CH4(10)                 	Rate Rules
# 273 	C7H15(680) + NC3H7(93) <=> C3H6(12) + C7H16(1)              	Rate Rules
# 274 	C7H15(680) <=> C7H15(682)                                   	Rate Rules
# 275 	C7H15(680) + C7H16(1) <=> C7H15(682) + C7H16(1)             	Rate Rules
# 276 	C7H15(680) <=> C7H15(679)                                   	Rate Rules
# 277 	C7H15(680) + C7H16(1) <=> C7H15(679) + C7H16(1)             	Rate Rules
# 278 	C7H15(680) + O2(2) <=> S(858)                               	Rate Rules
# 279 	S(858) <=> S(867)                                           	Rate Rules
# 280 	O2(2) + S(867) <=> S(889)                                   	Rate Rules
# 281 	S(438) <=> S(448)                                           	Library
# 282 	S(889) <=> OH(15) + S(910)                                  	Rate Rules
# 283 	S(185) <=> S(221)                                           	Library
# 284 	S(221) <=> S(220)                                           	PDep
# 285 	S(220) <=> CH2(24) + S(115)                                 	PDep
# 286 	S(221) <=> CH2(24) + S(115)                                 	PDep
# 287 	C7H15(683) + H(14) <=> C7H16(1)                             	Rate Rules
# 288 	C7H15(683) + HO2(17) <=> C7H16(1) + O2(2)                   	Rate Rules
# 289 	C7H16(1) + O(5) <=> C7H15(683) + OH(15)                     	Rate Rules
# 290 	C7H16(1) + OH(15) <=> C7H15(683) + H2O(8)                   	Rate Rules
# 291 	C7H15(683) + H2O2(18) <=> C7H16(1) + HO2(17)                	Rate Rules
# 292 	C2H5(44) + C7H15(683) <=> C2H4(11) + C7H16(1)               	Rate Rules
# 293 	C7H16(1) + H(14) <=> C7H15(683) + H2(13)                    	Rate Rules
# 294 	C7H16(1) + CH3(19) <=> C7H15(683) + CH4(10)                 	Rate Rules
# 295 	C7H15(683) + NC3H7(93) <=> C3H6(12) + C7H16(1)              	Rate Rules
# 296 	C7H15(683) <=> C7H15(682)                                   	Training
# 297 	C7H15(683) <=> C7H15(682)                                   	Training
# 298 	C7H15(683) + C7H16(1) <=> C7H15(682) + C7H16(1)             	Rate Rules
# 299 	C7H15(683) <=> C7H15(679)                                   	Rate Rules
# 300 	C7H15(683) <=> C7H15(679)                                   	Rate Rules
# 301 	C7H15(683) + C7H16(1) <=> C7H15(679) + C7H16(1)             	Rate Rules
# 302 	C7H15(683) <=> C7H15(680)                                   	Rate Rules
# 303 	C7H15(683) + C7H16(1) <=> C7H15(680) + C7H16(1)             	Rate Rules
# 304 	C2H4(11) + C5H11(421) <=> C7H15(683)                        	Training
# 305 	C7H15(683) <=> C7H15(682)                                   	Training
# 306 	C7H15(683) <=> C7H15(679)                                   	Rate Rules
# 307 	C7H15(679) <=> C7H15(683)                                   	Rate Rules
# 308 	C7H15(683) <=> C7H15(682)                                   	Training
# 309 	C7H15(683) + O2(2) <=> S(969)                               	Rate Rules
# 310 	S(816) <=> S(834)                                           	Rate Rules
# 311 	S(782) <=> S(763)                                           	Rate Rules
# 312 	O2(2) + S(782) <=> S(1025)                                  	Rate Rules
# 313 	S(835) <=> S(816)                                           	Rate Rules
# 314 	S(834) <=> S(835)                                           	Rate Rules
# 315 	S(1048) <=> S(1025)                                         	Rate Rules
# 316 	O2(2) + S(835) <=> S(1048)                                  	Rate Rules
# 317 	O2(2) + S(220) <=> S(226)                                   	Library
# 318 	S(782) <=> OH(15) + S(1011)                                 	Rate Rules
# 319 	S(835) <=> OH(15) + S(1011)                                 	Rate Rules
# 320 	C7H15(679) + S(785) <=> C7H16(1) + S(763)                   	Rate Rules
# 321 	C7H15(680) + S(785) <=> C7H16(1) + S(763)                   	Rate Rules
# 322 	C7H15(682) + S(785) <=> C7H16(1) + S(763)                   	Rate Rules
# 323 	C7H15(683) + S(785) <=> C7H16(1) + S(763)                   	Rate Rules
# 324 	C7H16(1) + S(782) <=> C7H15(679) + S(785)                   	Rate Rules
# 325 	C7H15(680) + S(785) <=> C7H16(1) + S(782)                   	Rate Rules
# 326 	C7H16(1) + S(782) <=> C7H15(682) + S(785)                   	Rate Rules
# 327 	C7H15(683) + S(785) <=> C7H16(1) + S(782)                   	Rate Rules
# 328 	C7H15(682) + HO2(17) <=> S(785)                             	Rate Rules
# 329 	H(14) + S(763) <=> S(785)                                   	Rate Rules
# 330 	H(14) + S(782) <=> S(785)                                   	Rate Rules
# 331 	HO2(17) + S(763) <=> O2(2) + S(785)                         	Rate Rules
# 332 	HO2(17) + S(782) <=> O2(2) + S(785)                         	Rate Rules
# 333 	C7H15(679) + S(837) <=> C7H16(1) + S(816)                   	Rate Rules
# 334 	C7H15(680) + S(837) <=> C7H16(1) + S(816)                   	Rate Rules
# 335 	C7H15(682) + S(837) <=> C7H16(1) + S(816)                   	Rate Rules
# 336 	C7H15(683) + S(837) <=> C7H16(1) + S(816)                   	Rate Rules
# 337 	C7H16(1) + S(834) <=> C7H15(679) + S(837)                   	Rate Rules
# 338 	C7H16(1) + S(834) <=> C7H15(680) + S(837)                   	Rate Rules
# 339 	C7H16(1) + S(834) <=> C7H15(682) + S(837)                   	Rate Rules
# 340 	C7H16(1) + S(834) <=> C7H15(683) + S(837)                   	Rate Rules
# 341 	C7H16(1) + S(835) <=> C7H15(679) + S(837)                   	Rate Rules
# 342 	C7H15(680) + S(837) <=> C7H16(1) + S(835)                   	Rate Rules
# 343 	C7H16(1) + S(835) <=> C7H15(682) + S(837)                   	Rate Rules
# 344 	C7H15(683) + S(837) <=> C7H16(1) + S(835)                   	Rate Rules
# 345 	C7H15(679) + HO2(17) <=> S(837)                             	Rate Rules
# 346 	H(14) + S(816) <=> S(837)                                   	Rate Rules
# 347 	H(14) + S(835) <=> S(837)                                   	Rate Rules
# 348 	H(14) + S(834) <=> S(837)                                   	Rate Rules
# 349 	HO2(17) + S(816) <=> O2(2) + S(837)                         	Rate Rules
# 350 	HO2(17) + S(835) <=> O2(2) + S(837)                         	Rate Rules
# 351 	HO2(17) + S(834) <=> O2(2) + S(837)                         	Rate Rules
# 352 	C7H15(679) + S(985) <=> C7H16(1) + S(969)                   	Rate Rules
# 353 	C7H15(680) + S(985) <=> C7H16(1) + S(969)                   	Rate Rules
# 354 	C7H15(682) + S(985) <=> C7H16(1) + S(969)                   	Rate Rules
# 355 	C7H15(683) + S(985) <=> C7H16(1) + S(969)                   	Rate Rules
# 356 	C7H15(683) + HO2(17) <=> S(985)                             	Rate Rules
# 357 	H(14) + S(969) <=> S(985)                                   	Rate Rules
# 358 	NC3H7(93) + S(221) <=> S(985)                               	Rate Rules
# 359 	PC4H9(183) + S(115) <=> S(985)                              	Rate Rules
# 360 	HO2(17) + S(969) <=> O2(2) + S(985)                         	Rate Rules
# 361 	S(226) <=> S(239)                                           	Library
# 362 	C2H3(23) + H2O2(18) <=> C2H4(11) + HO2(17)                  	Training
# 363 	H2O2(18) + S(763) <=> HO2(17) + S(785)                      	Rate Rules
# 364 	H2O2(18) + S(782) <=> HO2(17) + S(785)                      	Rate Rules
# 365 	H2O2(18) + S(816) <=> HO2(17) + S(837)                      	Rate Rules
# 366 	H2O2(18) + S(835) <=> HO2(17) + S(837)                      	Rate Rules
# 367 	H2O2(18) + S(834) <=> HO2(17) + S(837)                      	Rate Rules
# 368 	H2O2(18) + S(969) <=> HO2(17) + S(985)                      	Rate Rules
# 369 	C2H5(44) + HO2(17) <=> C2H4(11) + H2O2(18)                  	Rate Rules
# 370 	HO2(17) + NC3H7(93) <=> C3H6(12) + H2O2(18)                 	Rate Rules
# 371 	C7H15(679) + CH3CO(21) <=> C7H16(1) + CH2CO(25)             	Rate Rules
# 372 	C7H15(680) + CH3CO(21) <=> C7H16(1) + CH2CO(25)             	Rate Rules
# 373 	C7H15(682) + CH3CO(21) <=> C7H16(1) + CH2CO(25)             	Rate Rules
# 374 	C7H15(683) + CH3CO(21) <=> C7H16(1) + CH2CO(25)             	Rate Rules
# 375 	C7H15(679) + CH2CHO(22) <=> C7H16(1) + CH2CO(25)            	Rate Rules
# 376 	C7H15(680) + CH2CHO(22) <=> C7H16(1) + CH2CO(25)            	Rate Rules
# 377 	C7H15(682) + CH2CHO(22) <=> C7H16(1) + CH2CO(25)            	Rate Rules
# 378 	C7H15(683) + CH2CHO(22) <=> C7H16(1) + CH2CO(25)            	Rate Rules
# 379 	C2H3(23) + C7H15(679) <=> C2H2(26) + C7H16(1)               	Rate Rules
# 380 	C2H3(23) + C7H15(680) <=> C2H2(26) + C7H16(1)               	Rate Rules
# 381 	C2H3(23) + C7H15(682) <=> C2H2(26) + C7H16(1)               	Rate Rules
# 382 	C2H3(23) + C7H15(683) <=> C2H2(26) + C7H16(1)               	Rate Rules
# 383 	C2H2(26) + O2(2) <=> C2H(4) + HO2(17)                       	Training
# 384 	C7H15(679) + HCO(20) <=> C7H16(1) + CO(6)                   	Rate Rules
# 385 	C7H15(680) + HCO(20) <=> C7H16(1) + CO(6)                   	Rate Rules
# 386 	C7H15(682) + HCO(20) <=> C7H16(1) + CO(6)                   	Rate Rules
# 387 	C7H15(683) + HCO(20) <=> C7H16(1) + CO(6)                   	Rate Rules
# 388 	C2H5(44) + OH(15) <=> C2H4(11) + H2O(8)                     	Training
# 389 	NC3H7(93) + OH(15) <=> C3H6(12) + H2O(8)                    	Training
# 390 	OH(15) + S(785) <=> H2O(8) + S(763)                         	Rate Rules
# 391 	OH(15) + S(837) <=> H2O(8) + S(816)                         	Rate Rules
# 392 	C2H5(44) + HCO(20) <=> C2H4(11) + CH2O(9)                   	Rate Rules
# 393 	HCO(20) + NC3H7(93) <=> C3H6(12) + CH2O(9)                  	Rate Rules
# 394 	CH3(19) + NC3H7(93) <=> C3H6(12) + CH4(10)                  	Training
# 395 	C2H3(23) + NC3H7(93) <=> C2H4(11) + C3H6(12)                	Training
# 396 	C2H5(44) + S(763) <=> C2H4(11) + S(785)                     	Rate Rules
# 397 	C2H5(44) + S(782) <=> C2H4(11) + S(785)                     	Rate Rules
# 398 	C2H5(44) + S(816) <=> C2H4(11) + S(837)                     	Rate Rules
# 399 	C2H5(44) + S(835) <=> C2H4(11) + S(837)                     	Rate Rules
# 400 	C2H5(44) + S(834) <=> C2H4(11) + S(837)                     	Rate Rules
# 401 	C2H5(44) + S(969) <=> C2H4(11) + S(985)                     	Rate Rules
# 402 	NC3H7(93) + S(763) <=> C3H6(12) + S(785)                    	Rate Rules
# 403 	NC3H7(93) + S(782) <=> C3H6(12) + S(785)                    	Rate Rules
# 404 	NC3H7(93) + S(816) <=> C3H6(12) + S(837)                    	Rate Rules
# 405 	NC3H7(93) + S(835) <=> C3H6(12) + S(837)                    	Rate Rules
# 406 	NC3H7(93) + S(834) <=> C3H6(12) + S(837)                    	Rate Rules
# 407 	NC3H7(93) + S(969) <=> C3H6(12) + S(985)                    	Rate Rules
# 408 	S(239) <=> OH(15) + S(253)                                  	Library
# 409 	S(1025) <=> S(1045)                                         	Rate Rules
# 410 	S(1045) <=> S(1048)                                         	Rate Rules
# 411 	PC4H9(183) <=> SC4H9(184)                                   	Library
# 412 	PC4H9(183) <=> SC4H9(184)                                   	Library
# 413 	SC4H9(184) <=> C3H6(12) + CH3(19)                           	Library
# 414 	O(5) + S(970) <=> S(969)                                    	Rate Rules
# 415 	OH(15) + S(970) <=> S(985)                                  	Rate Rules
# 416 	C7H15(683) + O(5) <=> S(970)                                	Rate Rules
# 417 	S(970) <=> S(1273)                                          	Rate Rules
# 418 	H(14) + IC3H7(94) <=> C2H5(44) + CH3(19)                    	Library
# 419 	IC3H7(94) + OH(15) <=> C3H6(12) + H2O(8)                    	Library
# 420 	C3H6(12) + HO2(17) <=> IC3H7(94) + O2(2)                    	Library
# 421 	C3H6(12) + H(14) <=> IC3H7(94)                              	Library
# 422 	C3H6(12) + H(14) <=> IC3H7(94)                              	Library
# 423 	C7H15(679) + IC3H7(94) <=> C3H6(12) + C7H16(1)              	Rate Rules
# 424 	C7H15(680) + IC3H7(94) <=> C3H6(12) + C7H16(1)              	Rate Rules
# 425 	C7H15(682) + IC3H7(94) <=> C3H6(12) + C7H16(1)              	Rate Rules
# 426 	C7H15(683) + IC3H7(94) <=> C3H6(12) + C7H16(1)              	Rate Rules
# 427 	NC3H7(93) <=> IC3H7(94)                                     	PDep
# 428 	HO2(17) + IC3H7(94) <=> C3H6(12) + H2O2(18)                 	Rate Rules
# 429 	HCO(20) + IC3H7(94) <=> C3H6(12) + CH2O(9)                  	Rate Rules
# 430 	CH3(19) + IC3H7(94) <=> C3H6(12) + CH4(10)                  	Rate Rules
# 431 	C2H3(23) + IC3H7(94) <=> C2H4(11) + C3H6(12)                	Rate Rules
# 432 	IC3H7(94) + S(763) <=> C3H6(12) + S(785)                    	Rate Rules
# 433 	IC3H7(94) + S(782) <=> C3H6(12) + S(785)                    	Rate Rules
# 434 	IC3H7(94) + S(816) <=> C3H6(12) + S(837)                    	Rate Rules
# 435 	IC3H7(94) + S(835) <=> C3H6(12) + S(837)                    	Rate Rules
# 436 	IC3H7(94) + S(834) <=> C3H6(12) + S(837)                    	Rate Rules
# 437 	IC3H7(94) + S(969) <=> C3H6(12) + S(985)                    	Rate Rules
# 438 	IC3H7(94) <=> C2H5(44) + CH2(24)                            	PDep
# 439 	C4H8(189) + H(14) <=> PC4H9(183)                            	Library
# 440 	C4H8(189) + H(14) <=> SC4H9(184)                            	Library
# 441 	O2(2) + PC4H9(183) <=> C4H8(189) + HO2(17)                  	Library
# 442 	O2(2) + SC4H9(184) <=> C4H8(189) + HO2(17)                  	Library
# 443 	C2H3(23) + C2H5(44) <=> C4H8(189)                           	Library
# 444 	S(185) <=> C4H8(189) + HO2(17)                              	Library
# 445 	S(443) => C4H8(189) + CH2O(9) + OH(15)                      	Library
# 446 	C4H8(189) + NC3H7(93) <=> C7H15(679)                        	Rate Rules
# 447 	2 C2H4(11) <=> C4H8(189)                                    	PDep
# 448 	C7H15(679) + PC4H9(183) <=> C4H8(189) + C7H16(1)            	Rate Rules
# 449 	C7H15(679) + SC4H9(184) <=> C4H8(189) + C7H16(1)            	Rate Rules
# 450 	C7H15(680) + PC4H9(183) <=> C4H8(189) + C7H16(1)            	Rate Rules
# 451 	C7H15(680) + SC4H9(184) <=> C4H8(189) + C7H16(1)            	Rate Rules
# 452 	C7H15(682) + PC4H9(183) <=> C4H8(189) + C7H16(1)            	Rate Rules
# 453 	C7H15(682) + SC4H9(184) <=> C4H8(189) + C7H16(1)            	Rate Rules
# 454 	C7H15(683) + PC4H9(183) <=> C4H8(189) + C7H16(1)            	Rate Rules
# 455 	C7H15(683) + SC4H9(184) <=> C4H8(189) + C7H16(1)            	Rate Rules
# 456 	OH(15) + S(985) <=> H2O(8) + S(969)                         	Rate Rules
# 457 	S(782) + S(785) <=> S(763) + S(785)                         	Rate Rules
# 458 	S(785) + S(816) <=> S(763) + S(837)                         	Rate Rules
# 459 	S(785) + S(835) <=> S(763) + S(837)                         	Rate Rules
# 460 	S(785) + S(834) <=> S(763) + S(837)                         	Rate Rules
# 461 	S(785) + S(969) <=> S(763) + S(985)                         	Rate Rules
# 462 	S(782) + S(837) <=> S(785) + S(816)                         	Rate Rules
# 463 	S(835) + S(837) <=> S(816) + S(837)                         	Rate Rules
# 464 	S(834) + S(837) <=> S(816) + S(837)                         	Rate Rules
# 465 	S(837) + S(969) <=> S(816) + S(985)                         	Rate Rules
# 466 	S(782) + S(985) <=> S(785) + S(969)                         	Rate Rules
# 467 	S(835) + S(985) <=> S(837) + S(969)                         	Rate Rules
# 468 	S(834) + S(985) <=> S(837) + S(969)                         	Rate Rules
# 469 	O2(2) + S(1273) <=> S(1307)                                 	Rate Rules
# 470 	CH3(19) + O2(2) (+M) <=> CH3O2(40) (+M)                     	Library
# 471 	C7H14(808) + H(14) <=> C7H15(679)                           	Rate Rules
# 472 	C7H15(679) + O2(2) <=> C7H14(808) + HO2(17)                 	Rate Rules
# 473 	S(816) <=> C7H14(808) + HO2(17)                             	Rate Rules
# 474 	C7H14(808) + H(14) <=> C7H15(680)                           	Rate Rules
# 475 	C7H15(680) + O2(2) <=> C7H14(808) + HO2(17)                 	Rate Rules
# 476 	S(858) <=> C7H14(808) + HO2(17)                             	Rate Rules
# 477 	C7H15(679) + C7H15(680) <=> C7H14(808) + C7H16(1)           	Rate Rules
# 478 	2 C7H15(679) <=> C7H14(808) + C7H16(1)                      	Rate Rules
# 479 	2 C7H15(680) <=> C7H14(808) + C7H16(1)                      	Rate Rules
# 480 	C7H15(680) + C7H15(682) <=> C7H14(808) + C7H16(1)           	Rate Rules
# 481 	C7H15(679) + C7H15(682) <=> C7H14(808) + C7H16(1)           	Rate Rules
# 482 	C7H15(680) + C7H15(683) <=> C7H14(808) + C7H16(1)           	Rate Rules
# 483 	C7H15(679) + C7H15(683) <=> C7H14(808) + C7H16(1)           	Rate Rules
# 484 	C7H15(680) + OH(15) <=> C7H14(808) + H2O(8)                 	Rate Rules
# 485 	C7H15(679) + OH(15) <=> C7H14(808) + H2O(8)                 	Rate Rules
# 486 	C7H15(680) + S(763) <=> C7H14(808) + S(785)                 	Rate Rules
# 487 	C7H15(679) + S(763) <=> C7H14(808) + S(785)                 	Rate Rules
# 488 	C7H15(680) + S(782) <=> C7H14(808) + S(785)                 	Rate Rules
# 489 	C7H15(679) + S(782) <=> C7H14(808) + S(785)                 	Rate Rules
# 490 	S(1307) <=> S(1325)                                         	Rate Rules
# 491 	C7H15(679) + S(1049) <=> C7H16(1) + S(1025)                 	Rate Rules
# 492 	C7H15(680) + S(1049) <=> C7H16(1) + S(1025)                 	Rate Rules
# 493 	C7H15(682) + S(1049) <=> C7H16(1) + S(1025)                 	Rate Rules
# 494 	C7H15(683) + S(1049) <=> C7H16(1) + S(1025)                 	Rate Rules
# 495 	C7H15(679) + S(1049) <=> C7H16(1) + S(1048)                 	Rate Rules
# 496 	C7H15(680) + S(1049) <=> C7H16(1) + S(1048)                 	Rate Rules
# 497 	C7H15(682) + S(1049) <=> C7H16(1) + S(1048)                 	Rate Rules
# 498 	C7H15(683) + S(1049) <=> C7H16(1) + S(1048)                 	Rate Rules
# 499 	C7H16(1) + S(1045) <=> C7H15(679) + S(1049)                 	Rate Rules
# 500 	C7H16(1) + S(1045) <=> C7H15(680) + S(1049)                 	Rate Rules
# 501 	C7H16(1) + S(1045) <=> C7H15(682) + S(1049)                 	Rate Rules
# 502 	C7H16(1) + S(1045) <=> C7H15(683) + S(1049)                 	Rate Rules
# 503 	OH(15) + S(1049) <=> H2O(8) + S(1025)                       	Rate Rules
# 504 	OH(15) + S(1049) <=> H2O(8) + S(1048)                       	Rate Rules
# 505 	S(1049) + S(763) <=> S(1025) + S(785)                       	Rate Rules
# 506 	S(1049) + S(782) <=> S(1025) + S(785)                       	Rate Rules
# 507 	S(1049) + S(816) <=> S(1025) + S(837)                       	Rate Rules
# 508 	S(1049) + S(835) <=> S(1025) + S(837)                       	Rate Rules
# 509 	S(1049) + S(834) <=> S(1025) + S(837)                       	Rate Rules
# 510 	S(1049) + S(969) <=> S(1025) + S(985)                       	Rate Rules
# 511 	S(1049) + S(763) <=> S(1048) + S(785)                       	Rate Rules
# 512 	S(1049) + S(782) <=> S(1048) + S(785)                       	Rate Rules
# 513 	S(1049) + S(816) <=> S(1048) + S(837)                       	Rate Rules
# 514 	S(1049) + S(835) <=> S(1048) + S(837)                       	Rate Rules
# 515 	S(1049) + S(834) <=> S(1048) + S(837)                       	Rate Rules
# 516 	S(1049) + S(969) <=> S(1048) + S(985)                       	Rate Rules
# 517 	HO2(17) + S(835) <=> S(1049)                                	Rate Rules
# 518 	HO2(17) + S(782) <=> S(1049)                                	Rate Rules
# 519 	H(14) + S(1048) <=> S(1049)                                 	Rate Rules
# 520 	H(14) + S(1025) <=> S(1049)                                 	Rate Rules
# 521 	H(14) + S(1045) <=> S(1049)                                 	Rate Rules
# 522 	OH(15) + S(785) <=> H2O(8) + S(782)                         	Rate Rules
# 523 	OH(15) + S(837) <=> H2O(8) + S(835)                         	Rate Rules
# 524 	OH(15) + S(837) <=> H2O(8) + S(834)                         	Rate Rules
# 525 	OH(15) + S(1049) <=> H2O(8) + S(1045)                       	Rate Rules
# 526 	HO2(17) + S(1025) <=> O2(2) + S(1049)                       	Rate Rules
# 527 	HO2(17) + S(1048) <=> O2(2) + S(1049)                       	Rate Rules
# 528 	H2O2(18) + S(1048) <=> HO2(17) + S(1049)                    	Rate Rules
# 529 	H2O2(18) + S(1025) <=> HO2(17) + S(1049)                    	Rate Rules
# 530 	H2O2(18) + S(1045) <=> HO2(17) + S(1049)                    	Rate Rules
# 531 	C7H15(680) + HO2(17) <=> C7H14(808) + H2O2(18)              	Rate Rules
# 532 	C7H15(679) + HO2(17) <=> C7H14(808) + H2O2(18)              	Rate Rules
# 533 	HO2(17) + S(1045) <=> O2(2) + S(1049)                       	Rate Rules
# 534 	OH(15) + PC4H9(183) <=> C4H8(189) + H2O(8)                  	Rate Rules
# 535 	OH(15) + SC4H9(184) <=> C4H8(189) + H2O(8)                  	Rate Rules
# 536 	C2H5(44) + S(1048) <=> C2H4(11) + S(1049)                   	Rate Rules
# 537 	C2H5(44) + S(1025) <=> C2H4(11) + S(1049)                   	Rate Rules
# 538 	C2H5(44) + S(1045) <=> C2H4(11) + S(1049)                   	Rate Rules
# 539 	S(1045) + S(785) <=> S(1049) + S(763)                       	Rate Rules
# 540 	S(1045) + S(837) <=> S(1049) + S(816)                       	Rate Rules
# 541 	S(1045) + S(985) <=> S(1049) + S(969)                       	Rate Rules
# 542 	S(785) + S(834) <=> S(782) + S(837)                         	Rate Rules
# 543 	S(834) + S(837) <=> S(835) + S(837)                         	Rate Rules
# 544 	S(1048) + S(1049) <=> S(1025) + S(1049)                     	Rate Rules
# 545 	S(1045) + S(1049) <=> S(1025) + S(1049)                     	Rate Rules
# 546 	S(1045) + S(1049) <=> S(1048) + S(1049)                     	Rate Rules
# 547 	PC4H9(183) + S(763) <=> C4H8(189) + S(785)                  	Rate Rules
# 548 	S(763) + SC4H9(184) <=> C4H8(189) + S(785)                  	Rate Rules
# 549 	PC4H9(183) + S(782) <=> C4H8(189) + S(785)                  	Rate Rules
# 550 	S(782) + SC4H9(184) <=> C4H8(189) + S(785)                  	Rate Rules
# 551 	PC4H9(183) + S(816) <=> C4H8(189) + S(837)                  	Rate Rules
# 552 	S(816) + SC4H9(184) <=> C4H8(189) + S(837)                  	Rate Rules
# 553 	PC4H9(183) + S(835) <=> C4H8(189) + S(837)                  	Rate Rules
# 554 	S(835) + SC4H9(184) <=> C4H8(189) + S(837)                  	Rate Rules
# 555 	PC4H9(183) + S(834) <=> C4H8(189) + S(837)                  	Rate Rules
# 556 	S(834) + SC4H9(184) <=> C4H8(189) + S(837)                  	Rate Rules
# 557 	C7H15(680) + S(816) <=> C7H14(808) + S(837)                 	Rate Rules
# 558 	C7H15(679) + S(816) <=> C7H14(808) + S(837)                 	Rate Rules
# 559 	C7H15(680) + S(835) <=> C7H14(808) + S(837)                 	Rate Rules
# 560 	C7H15(679) + S(835) <=> C7H14(808) + S(837)                 	Rate Rules
# 561 	C7H15(680) + S(834) <=> C7H14(808) + S(837)                 	Rate Rules
# 562 	C7H15(679) + S(834) <=> C7H14(808) + S(837)                 	Rate Rules
# 563 	C7H15(680) + S(969) <=> C7H14(808) + S(985)                 	Rate Rules
# 564 	C7H15(679) + S(969) <=> C7H14(808) + S(985)                 	Rate Rules
# 565 	C7H15(680) + S(1048) <=> C7H14(808) + S(1049)               	Rate Rules
# 566 	C7H15(680) + S(1025) <=> C7H14(808) + S(1049)               	Rate Rules
# 567 	C7H15(680) + S(1045) <=> C7H14(808) + S(1049)               	Rate Rules
# 568 	C7H15(679) + S(1048) <=> C7H14(808) + S(1049)               	Rate Rules
# 569 	C7H15(679) + S(1025) <=> C7H14(808) + S(1049)               	Rate Rules
# 570 	C7H15(679) + S(1045) <=> C7H14(808) + S(1049)               	Rate Rules
# 571 	O2(2) + S(1325) <=> S(1370)                                 	Rate Rules
# 572 	S(781) <=> S(763)                                           	Rate Rules
# 573 	S(781) <=> S(782)                                           	Rate Rules
# 574 	H(14) + S(781) <=> S(785)                                   	Rate Rules
# 575 	HO2(17) + S(781) <=> O2(2) + S(785)                         	Rate Rules
# 576 	H2O2(18) + S(781) <=> HO2(17) + S(785)                      	Rate Rules
# 577 	C2H5(44) + S(781) <=> C2H4(11) + S(785)                     	Rate Rules
# 578 	NC3H7(93) + S(781) <=> C3H6(12) + S(785)                    	Rate Rules
# 579 	IC3H7(94) + S(781) <=> C3H6(12) + S(785)                    	Rate Rules
# 580 	S(781) + S(785) <=> S(763) + S(785)                         	Rate Rules
# 581 	S(781) + S(837) <=> S(785) + S(816)                         	Rate Rules
# 582 	S(781) + S(985) <=> S(785) + S(969)                         	Rate Rules
# 583 	S(1049) + S(781) <=> S(1025) + S(785)                       	Rate Rules
# 584 	S(1049) + S(781) <=> S(1048) + S(785)                       	Rate Rules
# 585 	C7H15(680) + S(781) <=> C7H14(808) + S(785)                 	Rate Rules
# 586 	C7H15(679) + S(781) <=> C7H14(808) + S(785)                 	Rate Rules
# 587 	OH(15) + S(785) <=> H2O(8) + S(781)                         	Rate Rules
# 588 	C7H16(1) + S(781) <=> C7H15(682) + S(785)                   	Rate Rules
# 589 	C7H16(1) + S(781) <=> C7H15(679) + S(785)                   	Rate Rules
# 590 	C7H15(683) + S(785) <=> C7H16(1) + S(781)                   	Rate Rules
# 591 	S(785) + S(834) <=> S(781) + S(837)                         	Rate Rules
# 592 	PC4H9(183) + S(781) <=> C4H8(189) + S(785)                  	Rate Rules
# 593 	S(781) + SC4H9(184) <=> C4H8(189) + S(785)                  	Rate Rules
# 594 	C7H15(680) + S(785) <=> C7H16(1) + S(781)                   	Rate Rules
# 595 	S(912) <=> S(889)                                           	Rate Rules
# 596 	O2(2) + S(781) <=> S(912)                                   	Rate Rules
# 597 	S(912) <=> OH(15) + S(910)                                  	Rate Rules
# 598 	S(889) <=> S(913)                                           	Rate Rules
# 599 	S(912) <=> S(913)                                           	Rate Rules
# 600 	C3H6(12) + S(239) <=> S(913)                                	Rate Rules
# 601 	S(913) <=> OH(15) + S(910)                                  	Rate Rules
# 602 	S(889) <=> OH(15) + S(907)                                  	Rate Rules
# 603 	S(912) <=> OH(15) + S(907)                                  	Rate Rules
# 604 	S(913) <=> OH(15) + S(907)                                  	Rate Rules
# 605 	O2(2) + S(913) <=> S(1469)                                  	Rate Rules
# 606 	C2H3(23) + C7H15(680) <=> C2H4(11) + C7H14(808)             	Rate Rules
# 607 	C2H3(23) + C7H15(679) <=> C2H4(11) + C7H14(808)             	Rate Rules
# 608 	S(1370) <=> OH(15) + S(1406)                                	Rate Rules
# 609 	C7H14(754) + H(14) <=> C7H15(682)                           	Rate Rules
# 610 	C7H15(682) + O2(2) <=> C7H14(754) + HO2(17)                 	Rate Rules
# 611 	S(763) <=> C7H14(754) + HO2(17)                             	Rate Rules
# 612 	C7H14(754) + H(14) <=> C7H15(679)                           	Rate Rules
# 613 	C7H15(679) + O2(2) <=> C7H14(754) + HO2(17)                 	Rate Rules
# 614 	S(816) <=> C7H14(754) + HO2(17)                             	Rate Rules
# 615 	C7H14(808) <=> C7H14(754)                                   	Rate Rules
# 616 	C7H14(754) <=> C3H6(12) + C4H8(189)                         	Rate Rules
# 617 	C7H15(680) + O(5) <=> C7H14(808) + OH(15)                   	Rate Rules
# 618 	C7H15(679) + O(5) <=> C7H14(808) + OH(15)                   	Rate Rules
# 619 	C7H15(682) + O(5) <=> C7H14(754) + OH(15)                   	Rate Rules
# 620 	C7H15(679) + O(5) <=> C7H14(754) + OH(15)                   	Rate Rules
# 621 	C7H15(682) + HO2(17) <=> C7H14(754) + H2O2(18)              	Rate Rules
# 622 	C7H15(679) + HO2(17) <=> C7H14(754) + H2O2(18)              	Rate Rules
# 623 	C7H15(679) + C7H15(682) <=> C7H14(754) + C7H16(1)           	Rate Rules
# 624 	2 C7H15(679) <=> C7H14(754) + C7H16(1)                      	Rate Rules
# 625 	C7H15(680) + C7H15(682) <=> C7H14(754) + C7H16(1)           	Rate Rules
# 626 	C7H15(679) + C7H15(680) <=> C7H14(754) + C7H16(1)           	Rate Rules
# 627 	2 C7H15(682) <=> C7H14(754) + C7H16(1)                      	Rate Rules
# 628 	C7H15(682) + C7H15(683) <=> C7H14(754) + C7H16(1)           	Rate Rules
# 629 	C7H15(679) + C7H15(683) <=> C7H14(754) + C7H16(1)           	Rate Rules
# 630 	HCO(20) + S(763) <=> CO(6) + S(785)                         	Rate Rules
# 631 	HCO(20) + S(782) <=> CO(6) + S(785)                         	Rate Rules
# 632 	HCO(20) + S(781) <=> CO(6) + S(785)                         	Rate Rules
# 633 	HCO(20) + S(816) <=> CO(6) + S(837)                         	Rate Rules
# ...
# 2060 	C2H5O2(45) + C5H11(422) <=> C2H6O2(46) + C5H10(425)         	Rate Rules
# 2061 	C5H11(422) + CH3O2(40) <=> C5H10(425) + CH3O2H(41)          	Rate Rules
# 2062 	C2H5O2(45) + S(1270) <=> C2H6O2(46) + S(979)                	Rate Rules
# 2063 	C2H5O2(45) + S(970) <=> C2H6O2(46) + S(979)                 	Rate Rules
# 2064 	CH3O2(40) + S(1270) <=> CH3O2H(41) + S(979)                 	Rate Rules
# 2065 	CH3O2(40) + S(970) <=> CH3O2H(41) + S(979)                  	Rate Rules
# 2066 	CH3O2H(41) <=> CH3O2(40) + H(14)                            	PDep
# 2067 	C2H3(23) + C2H5O2(45) <=> C2H2(26) + C2H6O2(46)             	Rate Rules
# 2068 	C2H5(44) + HO2(17) <=> C2H5O(48) + OH(15)                   	Library
# 2069 	C2H5(44) + CH3O2(40) <=> C2H5O(48) + CH3O(32)               	Library
# 2070 	C2H5O(48) + O2(2) <=> CH3CHO(47) + HO2(17)                  	Library
# 2071 	CH2O(9) + CH3(19) <=> C2H5O(48)                             	Library
# 2072 	CH3CHO(47) + H(14) <=> C2H5O(48)                            	Library
# 2073 	C2H6O2(46) <=> C2H5O(48) + OH(15)                           	Library
# 2074 	C2H4(11) + C2H5O2(45) <=> C2H4O(50) + C2H5O(48)             	Library
# 2075 	C2H5O2(45) <=> C2H5O(48) + O(5)                             	PDep
# 2076 	C2H5O(48) + C7H15(679) <=> C7H16(1) + CH3CHO(47)            	Rate Rules
# 2077 	C2H5O(48) + C7H15(680) <=> C7H16(1) + CH3CHO(47)            	Rate Rules
# 2078 	C2H5O(48) + C7H15(682) <=> C7H16(1) + CH3CHO(47)            	Rate Rules
# 2079 	C2H5O(48) + C7H15(683) <=> C7H16(1) + CH3CHO(47)            	Rate Rules
# 2080 	C2H5O(48) + HO2(17) <=> CH3CHO(47) + H2O2(18)               	Rate Rules
# 2081 	C2H5O(48) + OH(15) <=> CH3CHO(47) + H2O(8)                  	Rate Rules
# 2082 	C2H5O(48) + S(763) <=> CH3CHO(47) + S(785)                  	Rate Rules
# 2083 	C2H5O(48) + S(782) <=> CH3CHO(47) + S(785)                  	Rate Rules
# 2084 	C2H5O(48) + S(781) <=> CH3CHO(47) + S(785)                  	Rate Rules
# 2085 	C2H5O(48) + S(816) <=> CH3CHO(47) + S(837)                  	Rate Rules
# 2086 	C2H5O(48) + S(835) <=> CH3CHO(47) + S(837)                  	Rate Rules
# 2087 	C2H5O(48) + S(834) <=> CH3CHO(47) + S(837)                  	Rate Rules
# 2088 	C2H5O(48) + S(969) <=> CH3CHO(47) + S(985)                  	Rate Rules
# 2089 	C2H5O(48) + S(982) <=> CH3CHO(47) + S(985)                  	Rate Rules
# 2090 	C2H5O(48) + S(1048) <=> CH3CHO(47) + S(1049)                	Rate Rules
# 2091 	C2H5O(48) + S(1025) <=> CH3CHO(47) + S(1049)                	Rate Rules
# 2092 	C2H5O(48) + S(1045) <=> CH3CHO(47) + S(1049)                	Rate Rules
# 2093 	C2H5O(48) + CH2CHO(22) <=> 2 CH3CHO(47)                     	Rate Rules
# 2094 	C2H5O(48) + CH3CO(21) <=> 2 CH3CHO(47)                      	Rate Rules
# 2095 	C2H5O(48) + HCO(20) <=> CH2O(9) + CH3CHO(47)                	Rate Rules
# 2096 	C2H3(23) + C2H5O(48) <=> C2H4(11) + CH3CHO(47)              	Rate Rules
# 2097 	C2H5O(48) + CH3(19) <=> CH3CHO(47) + CH4(10)                	Rate Rules
# 2098 	C2H5O(48) + CH2(24) <=> CH3(19) + CH3CHO(47)                	Rate Rules
# 2099 	C2H5O(48) + H(14) <=> CH3CHO(47) + H2(13)                   	Rate Rules
# 2100 	2 CH3CHO(47) <=> C2H5O(48) + CH2CHO(22)                     	PDep
# 2101 	C2H5O(48) + C5H9O(848) <=> CH3CHO(47) + S(454)              	Rate Rules
# 2102 	C2H5O(48) + O(5) <=> CH3CHO(47) + OH(15)                    	Rate Rules
# 2103 	C2H5O(48) + C4H7(191) <=> C4H8(189) + CH3CHO(47)            	Rate Rules
# 2104 	C2H5O(48) + C4H7(192) <=> C4H8(189) + CH3CHO(47)            	Rate Rules
# 2105 	C2H5O(48) + C4H7(191) <=> C4H8(190) + CH3CHO(47)            	Rate Rules
# 2106 	C2H5(44) + C2H5O(48) <=> C2H6(43) + CH3CHO(47)              	Rate Rules
# 2107 	C2H(4) + C2H5O(48) <=> C2H2(26) + CH3CHO(47)                	Rate Rules
# 2108 	C3H5O2(72) <=> C2H5O(48) + CO(6)                            	PDep
# 2109 	C2H5O(48) + C2H5O2(45) <=> C2H6O2(46) + CH3CHO(47)          	Rate Rules
# 2110 	C2H5O(48) + CH3O2(40) <=> CH3CHO(47) + CH3O2H(41)           	Rate Rules
# 2111 	S(781) + S(985) <=> S(785) + S(982)                         	Rate Rules
# 2112 	C2H5O(48) <=> C2H5(44) + O(5)                               	PDep
# 2113 	H(14) + S(454) <=> C5H9O(848) + H2(13)                      	Rate Rules
# 2114 	C4H7(192) + O2(2) <=> S(24949)                              	PDep
# 2115 	C4H7(192) + O2(2) <=> S(10720)                              	PDep
# 2116 	C4H7(192) + O2(2) <=> C4H7(191) + O2(2)                     	PDep
# 2117 	C4H7(192) + O2(2) <=> C4H6O(264) + OH(15)                   	PDep
# 2118 	H(14) + S(1342) <=> C7H14(808)                              	Rate Rules
# 2119 	HO2(17) + S(1342) <=> C7H14(808) + O2(2)                    	Rate Rules
# 2120 	C7H15(680) + S(1342) <=> 2 C7H14(808)                       	Rate Rules
# 2121 	C7H15(679) + S(1342) <=> 2 C7H14(808)                       	Rate Rules
# 2122 	C7H14(808) + HO2(17) <=> H2O2(18) + S(1342)                 	Rate Rules
# 2123 	C7H14(808) + S(763) <=> S(1342) + S(785)                    	Rate Rules
# 2124 	C7H14(808) + S(816) <=> S(1342) + S(837)                    	Rate Rules
# 2125 	C7H14(808) + S(969) <=> S(1342) + S(985)                    	Rate Rules
# 2126 	C7H14(808) + S(1025) <=> S(1049) + S(1342)                  	Rate Rules
# 2127 	C7H14(808) + S(1048) <=> S(1049) + S(1342)                  	Rate Rules
# 2128 	NC3H7(93) + S(1342) <=> C3H6(12) + C7H14(808)               	Rate Rules
# 2129 	IC3H7(94) + S(1342) <=> C3H6(12) + C7H14(808)               	Rate Rules
# 2130 	C2H5(44) + S(1342) <=> C2H4(11) + C7H14(808)                	Rate Rules
# 2131 	H(14) + S(1342) <=> C7H14(754)                              	Rate Rules
# 2132 	C7H14(808) + OH(15) <=> H2O(8) + S(1342)                    	Rate Rules
# 2133 	C7H14(754) + OH(15) <=> H2O(8) + S(1342)                    	Rate Rules
# 2134 	C7H14(754) + HO2(17) <=> H2O2(18) + S(1342)                 	Rate Rules
# 2135 	HO2(17) + S(1342) <=> C7H14(754) + O2(2)                    	Rate Rules
# 2136 	C2H5(44) + S(1342) <=> C2H4(11) + C7H14(754)                	Rate Rules
# 2137 	NC3H7(93) + S(1342) <=> C3H6(12) + C7H14(754)               	Rate Rules
# 2138 	IC3H7(94) + S(1342) <=> C3H6(12) + C7H14(754)               	Rate Rules
# 2139 	C7H14(808) + C7H15(682) <=> C7H16(1) + S(1342)              	Rate Rules
# 2140 	C7H14(754) + C7H15(682) <=> C7H16(1) + S(1342)              	Rate Rules
# 2141 	C7H14(754) + S(763) <=> S(1342) + S(785)                    	Rate Rules
# 2142 	C7H14(808) + C7H15(679) <=> C7H16(1) + S(1342)              	Rate Rules
# 2143 	C7H14(754) + C7H15(679) <=> C7H16(1) + S(1342)              	Rate Rules
# 2144 	C7H14(754) + S(816) <=> S(1342) + S(837)                    	Rate Rules
# 2145 	C7H14(754) + S(969) <=> S(1342) + S(985)                    	Rate Rules
# 2146 	C7H14(754) + S(1025) <=> S(1049) + S(1342)                  	Rate Rules
# 2147 	C7H14(754) + S(1048) <=> S(1049) + S(1342)                  	Rate Rules
# 2148 	PC4H9(183) + S(1342) <=> C4H8(189) + C7H14(808)             	Rate Rules
# 2149 	S(1342) + SC4H9(184) <=> C4H8(189) + C7H14(808)             	Rate Rules
# 2150 	PC4H9(183) + S(1342) <=> C4H8(189) + C7H14(754)             	Rate Rules
# 2151 	S(1342) + SC4H9(184) <=> C4H8(189) + C7H14(754)             	Rate Rules
# 2152 	C7H15(682) + S(1342) <=> C7H14(754) + C7H14(808)            	Rate Rules
# 2153 	C7H15(679) + S(1342) <=> C7H14(754) + C7H14(808)            	Rate Rules
# 2154 	C7H15(680) + S(1342) <=> C7H14(754) + C7H14(808)            	Rate Rules
# 2155 	C7H15(682) + S(1342) <=> 2 C7H14(754)                       	Rate Rules
# 2156 	C7H15(679) + S(1342) <=> 2 C7H14(754)                       	Rate Rules
# 2157 	C2H5O(48) + S(1342) <=> C7H14(808) + CH3CHO(47)             	Rate Rules
# 2158 	C2H5O(48) + S(1342) <=> C7H14(754) + CH3CHO(47)             	Rate Rules
# 2159 	HCO(20) + S(1342) <=> C7H14(808) + CO(6)                    	Rate Rules
# 2160 	HCO(20) + S(1342) <=> C7H14(754) + CO(6)                    	Rate Rules
# 2161 	CH3O(32) + S(1342) <=> C7H14(808) + CH2O(9)                 	Rate Rules
# 2162 	CH3O(32) + S(1342) <=> C7H14(754) + CH2O(9)                 	Rate Rules
# 2163 	CH3O2H(41) + S(1342) <=> C7H14(808) + CH3O2(40)             	Rate Rules
# 2164 	CH3O2H(41) + S(1342) <=> C7H14(754) + CH3O2(40)             	Rate Rules
# 2165 	C3H5O(133) + S(1342) <=> C3H4O(75) + C7H14(808)             	Rate Rules
# 2166 	C3H5O(130) + S(1342) <=> C3H4O(75) + C7H14(808)             	Rate Rules
# 2167 	C3H5O(133) + S(1342) <=> C3H4O(75) + C7H14(754)             	Rate Rules
# 2168 	C3H5O(130) + S(1342) <=> C3H4O(75) + C7H14(754)             	Rate Rules
# 2169 	CH4(10) + S(1342) <=> C7H14(808) + CH3(19)                  	Rate Rules
# 2170 	CH4(10) + S(1342) <=> C7H14(754) + CH3(19)                  	Rate Rules
# 2171 	S(1342) + SC4H9(184) <=> C4H8(190) + C7H14(808)             	Rate Rules
# 2172 	S(1342) + SC4H9(184) <=> C4H8(190) + C7H14(754)             	Rate Rules
# 2173 	C7H15(683) + S(1342) <=> C7H14(755) + C7H14(808)            	Rate Rules
# 2174 	C7H15(682) + S(1342) <=> C7H14(755) + C7H14(808)            	Rate Rules
# 2175 	C7H15(683) + S(1342) <=> C7H14(754) + C7H14(755)            	Rate Rules
# 2176 	C7H15(682) + S(1342) <=> C7H14(754) + C7H14(755)            	Rate Rules
# 2177 	C2H6O2(46) + S(1342) <=> C2H5O2(45) + C7H14(808)            	Rate Rules
# 2178 	C2H6O2(46) + S(1342) <=> C2H5O2(45) + C7H14(754)            	Rate Rules
# 2179 	C7H14(754) + CH2CHO(22) <=> CH3CHO(47) + S(1342)            	Rate Rules
# 2180 	CH3CO(21) + S(1342) <=> C7H14(754) + CH2CO(25)              	Rate Rules
# 2181 	CH2CHO(22) + S(1342) <=> C7H14(754) + CH2CO(25)             	Rate Rules
# 2182 	CH3CO(21) + S(1342) <=> C7H14(808) + CH2CO(25)              	Rate Rules
# 2183 	CH2CHO(22) + S(1342) <=> C7H14(808) + CH2CO(25)             	Rate Rules
# 2184 	OCHO(29) + S(1342) <=> C7H14(808) + CO2(7)                  	Rate Rules
# 2185 	OCHO(29) + S(1342) <=> C7H14(754) + CO2(7)                  	Rate Rules
# 2186 	C7H14(808) + CH2CHO(22) <=> CH3CHO(47) + S(1342)            	Rate Rules
# 2187 	C5H11(421) + S(1342) <=> C5H10(424) + C7H14(808)            	Rate Rules
# 2188 	C5H11(422) + S(1342) <=> C5H10(424) + C7H14(808)            	Rate Rules
# 2189 	C5H11(422) + S(1342) <=> C5H10(425) + C7H14(808)            	Rate Rules
# 2190 	C5H11(421) + S(1342) <=> C5H10(424) + C7H14(754)            	Rate Rules
# 2191 	C5H11(422) + S(1342) <=> C5H10(424) + C7H14(754)            	Rate Rules
# 2192 	C5H11(422) + S(1342) <=> C5H10(425) + C7H14(754)            	Rate Rules
# 2193 	S(1270) + S(1342) <=> C7H14(808) + S(979)                   	Rate Rules
# 2194 	S(1342) + S(970) <=> C7H14(808) + S(979)                    	Rate Rules
# 2195 	S(1270) + S(1342) <=> C7H14(754) + S(979)                   	Rate Rules
# 2196 	S(1342) + S(970) <=> C7H14(754) + S(979)                    	Rate Rules
# 2197 	C7H14(754) + C7H15(683) <=> C7H16(1) + S(1342)              	Rate Rules
# 2198 	C7H14(808) + C7H15(683) <=> C7H16(1) + S(1342)              	Rate Rules
# 2199 	C7H14(754) + S(782) <=> S(1342) + S(785)                    	Rate Rules
# 2200 	C7H14(754) + S(835) <=> S(1342) + S(837)                    	Rate Rules
# 2201 	C2H3(23) + S(1342) <=> C2H2(26) + C7H14(754)                	Rate Rules
# 2202 	C2H3(23) + S(1342) <=> C2H2(26) + C7H14(808)                	Rate Rules
# 2203 	C2H6(43) + S(1342) <=> C2H5(44) + C7H14(808)                	Rate Rules
# 2204 	C2H6(43) + S(1342) <=> C2H5(44) + C7H14(754)                	Rate Rules
# 2205 	C7H14(808) + S(782) <=> S(1342) + S(785)                    	Rate Rules
# 2206 	C7H14(808) + S(835) <=> S(1342) + S(837)                    	Rate Rules
# 2207 	C7H14(754) + C7H15(680) <=> C7H16(1) + S(1342)              	Rate Rules
# 2208 	C7H14(754) + S(1045) <=> S(1049) + S(1342)                  	Rate Rules
# 2209 	H2(13) + S(1342) <=> C7H14(754) + H(14)                     	Rate Rules
# 2210 	C4H8(189) + S(1342) <=> C4H7(191) + C7H14(808)              	Rate Rules
# 2211 	C4H8(190) + S(1342) <=> C4H7(191) + C7H14(808)              	Rate Rules
# 2212 	C4H8(189) + S(1342) <=> C4H7(191) + C7H14(754)              	Rate Rules
# 2213 	C4H8(190) + S(1342) <=> C4H7(191) + C7H14(754)              	Rate Rules
# 2214 	C7H14(808) + C7H15(680) <=> C7H16(1) + S(1342)              	Rate Rules
# 2215 	H2(13) + S(1342) <=> C7H14(808) + H(14)                     	Rate Rules
# 2216 	C7H14(754) + S(982) <=> S(1342) + S(985)                    	Rate Rules
# 2217 	C7H14(754) + S(834) <=> S(1342) + S(837)                    	Rate Rules
# 2218 	C4H7(192) + C7H14(754) <=> C4H8(189) + S(1342)              	Rate Rules
# 2219 	C7H14(754) + O(5) <=> OH(15) + S(1342)                      	Rate Rules
# 2220 	C7H14(808) + O(5) <=> OH(15) + S(1342)                      	Rate Rules
# 2221 	C7H14(754) + CH2(24) <=> CH3(19) + S(1342)                  	Rate Rules
# 2222 	C7H14(808) + CH2(24) <=> CH3(19) + S(1342)                  	Rate Rules
# 2223 	C2H(4) + C7H14(754) <=> C2H2(26) + S(1342)                  	Rate Rules
# 2224 	C2H(4) + C7H14(808) <=> C2H2(26) + S(1342)                  	Rate Rules
# 2225 	C7H14(754) + HCO(20) <=> CH2O(9) + S(1342)                  	Rate Rules
# 2226 	C7H14(808) + HCO(20) <=> CH2O(9) + S(1342)                  	Rate Rules
# 2227 	C2H4(11) + S(1342) <=> C2H3(23) + C7H14(754)                	Rate Rules
# 2228 	C2H4(11) + S(1342) <=> C2H3(23) + C7H14(808)                	Rate Rules
# 2229 	C5H9O(848) + C7H14(754) <=> S(1342) + S(454)                	Rate Rules
# 2230 	C5H9O(848) + C7H14(808) <=> S(1342) + S(454)                	Rate Rules
# 2231 	C7H14(754) + S(781) <=> S(1342) + S(785)                    	Rate Rules
# 2232 	C7H14(808) + S(781) <=> S(1342) + S(785)                    	Rate Rules
# 2233 	C7H14(808) + S(834) <=> S(1342) + S(837)                    	Rate Rules
# 2234 	C7H14(808) + S(982) <=> S(1342) + S(985)                    	Rate Rules
# 2235 	C4H7(192) + C7H14(808) <=> C4H8(189) + S(1342)              	Rate Rules
# 2236 	C7H14(808) + S(1342) <=> C7H14(754) + S(1342)               	Rate Rules
# 2237 	C7H14(808) + S(1045) <=> S(1049) + S(1342)                  	Rate Rules
# 2238 	C7H14(754) + CH3CO(21) <=> CH3CHO(47) + S(1342)             	Rate Rules
# 2239 	C7H14(808) + CH3CO(21) <=> CH3CHO(47) + S(1342)             	Rate Rules
# 2240 	O2(2) + S(1342) <=> S(28180)                                	Rate Rules
# 2241 	H(14) + S(785) <=> H2(13) + S(782)                          	Rate Rules
# 2242 	H(14) + S(785) <=> H2(13) + S(781)                          	Rate Rules
# 2243 	H(14) + S(837) <=> H2(13) + S(835)                          	Rate Rules
# 2244 	H(14) + S(837) <=> H2(13) + S(834)                          	Rate Rules
# 2245 	H(14) + S(1049) <=> H2(13) + S(1045)                        	Rate Rules
# 2246 	CH2O(9) + S(781) <=> HCO(20) + S(785)                       	Rate Rules
# 2247 	CH2O(9) + S(834) <=> HCO(20) + S(837)                       	Rate Rules
# 2248 	CH3CHO(47) + S(982) <=> CH3CO(21) + S(985)                  	Rate Rules
# 2249 	C2H(4) + S(785) <=> C2H2(26) + S(763)                       	Rate Rules
# 2250 	C2H(4) + S(837) <=> C2H2(26) + S(816)                       	Rate Rules
# 2251 	C2H(4) + S(985) <=> C2H2(26) + S(969)                       	Rate Rules
# 2252 	C2H(4) + S(1049) <=> C2H2(26) + S(1048)                     	Rate Rules
# 2253 	C2H3(23) + S(785) <=> C2H4(11) + S(782)                     	Rate Rules
# 2254 	C2H3(23) + S(837) <=> C2H4(11) + S(835)                     	Rate Rules
# 2255 	O2(2) + S(1342) <=> S(28179)                                	Rate Rules
# 2256 	S(28180) <=> S(28179)                                       	Rate Rules
# 2257 	S(28180) <=> S(28403)                                       	Rate Rules
# 2258 	S(28179) <=> S(28403)                                       	Rate Rules
# 2259 	S(28179) <=> S(31028)                                       	Rate Rules
# 2260 	C2H3(23) + C4H8(189) <=> C2H4(11) + C4H7(192)               	Rate Rules
# 2261 	C5H8(334) + OH(15) <=> C4H7(191) + CH2O(9)                  	Library
# 2262 	C5H8(334) + OH(15) <=> C2H5(44) + C3H4O(75)                 	Library
# 2263 	C2H2(26) + C3H6(12) <=> C5H8(334)                           	PDep
# 2264 	C2H5(44) + C5H8(334) <=> S(1342)                            	Rate Rules
# 2265 	CO(6) + PC4H9(183) <=> CH2CO(25) + NC3H7(93)                	PDep

# %% [markdown]
# # List the training reactions that contributed to a single reaction

# %%
reactions = gas1.reactions()
rxn_index = 1341

# 448 is a new trees reaction
# 1341 is an old tree

reaction = reactions[rxn_index]
source = mech_uncertainty['reactions'][rxn_index]['uncertainty']['source']

print(f'Reaction :\t{reaction}')
print(f'Source:\t\t{source}')

if source == 'Rate Rules' and 'sensitivities' in mech_uncertainty['reactions'][rxn_index]['uncertainty'].keys():
    print(f"Family:\t\t{mech_uncertainty['reactions'][rxn_index]['uncertainty']['family']}")
    print(f"Node:\t\t{mech_uncertainty['reactions'][rxn_index]['uncertainty']['rule_node']}")
    print('Training Reactions:\t\t\t\t\tdA_node/dA_train\tdE0_node/dA_train\tdn_node/dA_train')
    sensitivities = mech_uncertainty['reactions'][rxn_index]['uncertainty']['sensitivities']
    PAD = 50
    for j, sensitivity in enumerate(sensitivities):
        pad_length2 = PAD - len(sensitivity["training_rxn_name"])
        training_rxn_str = sensitivity["training_rxn_name"] + " " * pad_length2
        print(f'{j}\t{training_rxn_str}'+
              "{0:.6f}".format(sensitivity["dA"])+
              "\t\t{0:.6f}".format(sensitivity["dE0"])+
              "\t\t{0:.6f}".format(float(sensitivity["dn"])))
elif source == 'Rate Rules' and 'sensitivities' not in mech_uncertainty['reactions'][rxn_index]['uncertainty'].keys():
    print('Estimated using old trees')
    print(f"Family:\t\t{mech_uncertainty['reactions'][rxn_index]['uncertainty']['family']}")
    print(f"Exact match:\t{mech_uncertainty['reactions'][rxn_index]['uncertainty']['exact']}")
    print('Training Reactions:\t\t\t\t\tWeight')
    for j, uncertainty in enumerate(mech_uncertainty['reactions'][rxn_index]['uncertainty']['train_rxn_uncertainty']):
        try:
            pad_length2 = PAD - len(uncertainty["training_name"])
            training_rxn_str = uncertainty["training_name"] + " " * pad_length2
        except KeyError:
            pad_length2 = PAD - len(uncertainty["rule_name"])
            training_rxn_str = uncertainty["rule_name"] + " " * pad_length2
        print(f"{j}\t{training_rxn_str}"+"{0:.8f}".format(uncertainty['weight']))
    
else:
    print(mech_uncertainty['reactions'][rxn_index]['note'])
    print(f"Estimated uncertainty: {mech_uncertainty['reactions'][rxn_index]['uncertainty']['value']}")
# Out:
# Reaction :	OH(15) + S(454) <=> C5H9O(848) + H2O(8)
# Source:		Rate Rules
# Estimated using old trees
# Family:		H_Abstraction
# Exact match:	False
# Training Reactions:					Weight
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_31298/1397301805.py in <module>
#      31     for j, uncertainty in enumerate(mech_uncertainty['reactions'][rxn_index]['uncertainty']['train_rxn_uncertainty']):
#      32         try:
# ---> 33             pad_length2 = PAD - len(uncertainty["training_name"])
#      34             training_rxn_str = uncertainty["training_name"] + " " * pad_length2
#      35         except KeyError:
#
# NameError: name 'PAD' is not defined

# %% [markdown]
# # List the training reactions for every reaction

# %%
reactions = gas1.reactions()
for rxn_index, reaction in enumerate(reactions):
    source = mech_uncertainty['reactions'][rxn_index]['uncertainty']['source']

    print(f'Reaction {rxn_index}:\t{reaction}')
    print(f'Source:\t\t{source}')

    if source == 'Rate Rules' and 'sensitivities' in mech_uncertainty['reactions'][rxn_index]['uncertainty'].keys():
        print(f"Family:\t\t{mech_uncertainty['reactions'][rxn_index]['uncertainty']['family']}")
        print(f"Node:\t\t{mech_uncertainty['reactions'][rxn_index]['uncertainty']['rule_node']}")
        print('Training Reactions:\t\t\t\t\tdA_node/dA_train\tdE0_node/dA_train\tdn_node/dA_train')
        sensitivities = mech_uncertainty['reactions'][rxn_index]['uncertainty']['sensitivities']
        PAD = 50
        for j, sensitivity in enumerate(sensitivities):
            pad_length2 = PAD - len(sensitivity["training_rxn_name"])
            training_rxn_str = sensitivity["training_rxn_name"] + " " * pad_length2
            print(f'{j}\t{training_rxn_str}'+
               "{0:.6f}".format(sensitivity["dA"])+
               "\t\t{0:.6f}".format(sensitivity["dE0"])+
               "\t\t{0:.6f}".format(float(sensitivity["dn"])))
                
    elif source == 'Rate Rules' and 'sensitivities' not in mech_uncertainty['reactions'][rxn_index]['uncertainty'].keys():
        print('Estimated using old trees')
        print(f"Family:\t\t{mech_uncertainty['reactions'][rxn_index]['uncertainty']['family']}")
        print(f"Exact match:\t{mech_uncertainty['reactions'][rxn_index]['uncertainty']['exact']}")
        print('Training Reactions:\t\t\t\t\tWeight')
        for j, uncertainty in enumerate(mech_uncertainty['reactions'][rxn_index]['uncertainty']['train_rxn_uncertainty']):
            try:
                pad_length2 = PAD - len(uncertainty["training_name"])
                training_rxn_str = uncertainty["training_name"] + " " * pad_length2
            except KeyError:
                pad_length2 = PAD - len(uncertainty["rule_name"])
                training_rxn_str = uncertainty["rule_name"] + " " * pad_length2
            print(f"{j}\t{training_rxn_str}"+"{0:.8f}".format(uncertainty['weight']))
        
    else:
        print(mech_uncertainty['reactions'][rxn_index]['note'])
        print(f"Estimated uncertainty: {mech_uncertainty['reactions'][rxn_index]['uncertainty']['value']}")
    
    print()

# %% [markdown]
# # List the species thermo uncertainty sources

# %%
species = gas1.species()
print('Species:\tSource\t\tEstimated Uncertainty')
PAD3 = 15
for i, specimen in enumerate(species):
    source = mech_uncertainty['species'][i]['uncertainty']['source']
    pad_length3 = PAD3 - len(mech_uncertainty['species'][i]['name'])
    spec_str = mech_uncertainty['species'][i]['name'] + " " * pad_length3
    print(spec_str + source + "\t\t{0:.2f}".format(mech_uncertainty['species'][i]['uncertainty']['value']))

# %% [markdown]
# # List groups for species thermo estimated using Group Additivity Values

# %%
species = gas1.species()

PAD4 = 19
print('Species:')
for i, specimen in enumerate(species):
    source = mech_uncertainty['species'][i]['uncertainty']['source']
    if source != 'GAV':
        continue
    print(f"{mech_uncertainty['species'][i]['name']}")
    print("\tEntry Name\t\tIndex\tFrequency\tEntry Type")
    for group_entry in mech_uncertainty['species'][i]['uncertainty']['group_entries']:
        pad_length4 = PAD4 - len(group_entry['entry_name'])
        name_str = group_entry['entry_name'] + " " * pad_length4
        print(f"\t{name_str}\t{group_entry['entry_index']}\t{group_entry['entry_freq']}\t\t{group_entry['family_name']}")
    print()
